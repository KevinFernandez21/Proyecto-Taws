# %%
# Load environment variables

from dotenv import load_dotenv,find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
# Run basic query with OpenAI wrapper 
from langchain.llms import OpenAI 
from langchain import HuggingFaceHub
#llm = OpenAI(model_name="text-davinci-003") 
llm = HuggingFaceHub(repo_id="OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5")
llm("<|prompter|>podrias revisar una base de datos y darme un top de 10 mejores cosas?<|endoftext|><|assistant|>")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Run basic query with OpenAI wrapper
# ----> 2 from langchain.llms import OpenAI
#       3 from langchain import HuggingFaceHub
#       4 #llm = OpenAI(model_name="text-davinci-003")
#
# ModuleNotFoundError: No module named 'langchain'

# %% [markdown]
# # NETFLIX
# ### Datos generales

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
netflix_overall=pd.read_csv("practica_data/netflix_titles.csv")
netflix_overall_sorted = netflix_overall.sort_values(by='imdb_score', ascending=False)
netflix_overall_sorted.head(10)
# Out:
#             id                              title   type  \
# 2658  ts265844                           #ABtalks   SHOW
# 216        ts4                       Breaking Bad   SHOW
# 564   ts160526                           Khawatir   SHOW
# 3147   ts85398                         Our Planet   SHOW
# 233     ts3371         Avatar: The Last Airbender   SHOW
# 1258   ts37660                         Reply 1988   SHOW
# 3068   ts81120                     The Last Dance   SHOW
# 1092  tm250247  Chhota Bheem & Krishna vs Zimbara  MOVIE
# 4771  tm996762                              Major  MOVIE
# 3500   ts90621                       Kota Factory   SHOW
#
#                                             description  release_year  \
# 2658  #ABtalks is a YouTube interview show hosted by...          2018
# 216   When Walter White, a New Mexico chemistry teac...          2008
# 564   A TV show devoted to help young people to be m...          2005
# ...

# %% [markdown]
# # DISNEY
# ### Datos generales

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
disney_overall=pd.read_csv("practica_data/disney_plus_titles.csv")
disney_overall.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %% [markdown]
# # HULU
# ### Datos generales

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
hulu_overall=pd.read_csv("practica_data/hulu_titles.csv")
hulu_overall.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# ...

# %% [markdown]
# # PRIME VIDEO
# ### Datos generales

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
prime_video_overall=pd.read_csv("practica_data/amazon_prime_titles.csv")
prime_video_overall.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np # linear algebra
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'
